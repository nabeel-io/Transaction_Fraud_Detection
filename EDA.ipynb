# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_pickle("data/df.pickle")

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834784 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  \
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649
#
#             Amount  Class
# 284802    0.770000      0
# 284803   24.790001      0
# 284804   67.879997      0
# 284805   10.000000      0
# 284806  217.000000      0
#
# [5 rows x 31 columns]

# %%
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481387e+04  47488.144531    0.000000  54201.500000
# V1      284807.0  1.339397e-08      1.958696  -56.407509     -0.920373
# V2      284807.0  0.000000e+00      1.651309  -72.715729     -0.598550
# V3      284807.0 -4.800400e-08      1.516255  -48.325588     -0.890365
# V4      284807.0  6.643411e-09      1.415869   -5.683171     -0.848640
# V5      284807.0  2.657364e-08      1.380247 -113.743309     -0.691597
# V6      284807.0 -1.500125e-09      1.332271  -26.160505     -0.768296
# V7      284807.0 -1.071518e-09      1.237094  -43.557243     -0.554076
# V8      284807.0 -1.071518e-10      1.194353  -73.216721     -0.208630
# V9      284807.0 -3.214554e-10      1.098632  -13.434067     -0.643098
# V10     284807.0 -4.071768e-09      1.088850  -24.588263     -0.535426
# V11     284807.0  7.714928e-09      1.020713   -4.797473     -0.762494
# V12     284807.0  8.572143e-09      0.999201  -18.683714     -0.405571
# V13     284807.0  1.580489e-09      0.995274   -5.791881     -0.648539
# V14     284807.0 -3.107402e-09      0.958596  -19.214325     -0.425574
# V15     284807.0 -1.285821e-08      0.915316   -4.498945     -0.582884
# V16     284807.0  7.500625e-10      0.876253  -14.129854     -0.468037
# V17     284807.0 -2.625219e-09      0.849337  -25.162800     -0.483748
# V18     284807.0  2.357339e-09      0.838176   -9.498746     -0.498850
# V19     284807.0  2.678795e-10      0.814040   -7.213527     -0.456299
# V20     284807.0 -1.178670e-09      0.770925  -54.497719     -0.211721
# V21     284807.0 -1.928732e-09      0.734524  -34.830383     -0.228395
# V22     284807.0  3.643161e-09      0.725702  -10.933144     -0.542350
# V23     284807.0  3.214554e-10      0.624460  -44.807735     -0.161846
# V24     284807.0  1.259033e-09      0.605647   -2.836627     -0.354586
# V25     284807.0  2.143036e-09      0.521278  -10.295397     -0.317145
# V26     284807.0  1.034684e-09      0.482227   -2.604551     -0.326984
# V27     284807.0  1.138488e-10      0.403632  -22.565680     -0.070840
# V28     284807.0 -1.272427e-10      0.330083  -15.430084     -0.052960
# Amount  284807.0  8.834961e+01    250.120117    0.000000      5.600000
# Class   284807.0  1.727486e-03      0.041527    0.000000      0.000000
#
#                  50%            75%            max
# Time    84692.000000  139320.500000  172792.000000
# V1          0.018109       1.315642       2.454930
# V2          0.065486       0.803724      22.057730
# V3          0.179846       1.027196       9.382559
# V4         -0.019847       0.743341      16.875343
# V5         -0.054336       0.611926      34.801666
# V6         -0.274187       0.398565      73.301628
# V7          0.040103       0.570436     120.589493
# V8          0.022358       0.327346      20.007208
# V9         -0.051429       0.597139      15.594995
# V10        -0.092917       0.453923      23.745136
# V11        -0.032757       0.739593      12.018913
# V12         0.140033       0.618238       7.848392
# V13        -0.013568       0.662505       7.126883
# V14         0.050601       0.493150      10.526766
# V15         0.048072       0.648821       8.877742
# V16         0.066413       0.523296      17.315111
# V17        -0.065676       0.399675       9.253527
# V18        -0.003636       0.500807       5.041069
# V19         0.003735       0.458949       5.591971
# V20        -0.062481       0.133041      39.420906
# V21        -0.029450       0.186377      27.202839
# V22         0.006782       0.528554      10.503090
# V23        -0.011193       0.147642      22.528412
# V24         0.040976       0.439527       4.584549
# V25         0.016594       0.350716       7.519588
# V26        -0.052139       0.240952       3.517346
# V27         0.001342       0.091045      31.612198
# V28         0.011244       0.078280      33.847809
# Amount     22.000000      77.165001   25691.160156
# Class       0.000000       0.000000       1.000000

# %%
print("Proportion of Target Class")
print(df["Class"].value_counts()/len(df)*100)
# Out:
# Proportion of Target Class
# 0    99.827251
# 1     0.172749
# Name: Class, dtype: float64

# %%
sns.barplot(x=df["Class"].value_counts()/len(df), y=df["Class"].unique(), orient="h", color="hotpink");

# %%
# Distributions of features

# %%
fig, axes = plt.subplots(6, 5, figsize=(12,10))
col = df.columns[1:]
x = 0
for r in range(6):
    for c in range(5):
        sns.kdeplot(ax=axes[r,c],x=df[col[x]], y=None,fill=True, color="dodgerblue")
        x = x + 1
plt.tight_layout()

# %%
df["Time"].unique()
# Out:
# array([0.00000e+00, 1.00000e+00, 2.00000e+00, ..., 1.72787e+05,
#        1.72788e+05, 1.72792e+05], dtype=float32)

# %%
# boxplots
fig, ax = plt.subplots(1,2,figsize=(18,8))
sns.boxplot(data=df.iloc[:,1:-2], orient="h", color="deeppink",ax=ax[0])
ax[0].set_title("Attributes with outliers")
sns.boxplot(data=df.iloc[:,1:-2], orient="h", color="deeppink",showfliers=False, ax=ax[1])
ax[1].set_title("Boxplot without outliers");

# %%
fig, axes = plt.subplots(5, 6, figsize=(15,15))
col = df.columns[1:]
x = 0
for r in range(5):
    for c in range(6):
        sns.boxplot(ax = axes[r,c],data=df, x="Class", y=col[x], palette="cool",)
        x = x + 1
plt.tight_layout()

# %%
# heatmap

# %%
corr = np.round(df.iloc[:, 1:-1].corr(), 2)
plt.figure(figsize=(15,15))
sns.heatmap(corr , cmap="YlGnBu", linewidths=0.9, cbar=False, annot=True);

# %%
# decision tree baseline model

# %%
train = pd.read_pickle("data/train.pickle")
test = pd.read_pickle("data/test.pickle")

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix
dtc = DecisionTreeClassifier()
dtc.fit(train.iloc[:,:-1], train["Class"])
pred = dtc.predict(test.iloc[:,:-1])
print(classification_report(pred, test["Class"]))
print(confusion_matrix(pred, test["Class"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71076
#            1       0.72      0.71      0.71       126
#
#     accuracy                           1.00     71202
#    macro avg       0.86      0.85      0.86     71202
# weighted avg       1.00      1.00      1.00     71202
#
# [[71042    34]
#  [   37    89]]
